# %%
# %matplotlib inline

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
axis_size = 15
val_size = 17
title_size = 20

list_of_files = [
                ("aiidadb_davide_dj_1m_a_anc_query_raw.txt", "Number of ancestors"),
                ("aiidadb_davide_dj_1m_a_dsc_query_raw.txt", "Number of descendants")
                ]
p_title = "Descendants/ancestors popularity"
x_title = "Number of descendants/ancestors"
y_title = "Occurences"

data_limit = 300

plt.rc('axes', titlesize=axis_size)     # fontsize of the axes title
plt.rc('axes', labelsize=axis_size)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=axis_size)    # fontsize of the tick labels
plt.rc('ytick', labelsize=axis_size)    # fontsize of the tick labels
plt.rc('legend', fontsize=axis_size)    # legend fontsize

# %%
import pylab
import matplotlib.pyplot as plt
from scipy.interpolate import spline
import scipy.signal as signal
import pandas as pd

datalist = [ ( pylab.loadtxt(filename), label ) for filename, label in list_of_files ]

for data, label in datalist:
    pylab.plot( data[:data_limit,0], data[:data_limit,1], label=label )

pylab.legend()
pylab.title(p_title, fontsize=title_size)
pylab.xlabel(x_title)
pylab.ylabel(y_title)

# %%
import pylab
import matplotlib.pyplot as plt
from scipy.interpolate import spline
import scipy.signal as signal
import pandas as pd
from pandas import Series


datalist = [ ( pylab.loadtxt(filename), label ) for filename, label in list_of_files ]

plt.yscale('log')
for data, label in datalist:
    series = Series.from_array(data[:data_limit,1])
    rolling = series.rolling(window=10)
    rolling_mean = rolling.mean()
    pylab.plot( data[:data_limit,0], rolling_mean, label=label, linewidth=2)

pylab.legend()
pylab.title(p_title, fontsize=title_size)
pylab.xlabel(x_title)
pylab.ylabel(y_title + " (Log scale)")

# %%
import pylab
import matplotlib.pyplot as plt
from scipy.interpolate import spline
import scipy.signal as signal
import pandas as pd


datalist = [ ( pylab.loadtxt(filename), label ) for filename, label in list_of_files ]

plt.yscale('log')
for data, label in datalist:
    pylab.plot( data[:data_limit,0], data[:data_limit,1], label=label )

pylab.legend()
pylab.title(p_title, fontsize=title_size)
pylab.xlabel(x_title)
pylab.ylabel(y_title + " (Log scale)")
